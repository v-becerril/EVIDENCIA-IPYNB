# %%
import pandas as pd
df = pd.read_csv('MEXICO.csv')
print(df.shape)
print(df.columns)
# Out:
# (26401, 79)
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name',
#        'description', 'neighborhood_overview', 'picture_url', 'host_id',
#        'host_url', 'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d', 'availability_eoy',
#        'number_of_reviews_ly', 'estimated_occupancy_l365d',
#        'estimated_revenue_l365d', 'first_review', 'last_review',
#        'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'license', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object')

# %%
selcc_variables = ['host_since', 'host_response_time', 'host_is_superhost', 'neighbourhood_cleansed', 'room_type', 'accommodates', 'number_of_reviews', 'review_scores_cleanliness', 'review_scores_communication', 'review_scores_location']

## Creación de dataframe
df_selecc = df[selcc_variables]
df_selecc
# Out:
#        host_since  host_response_time host_is_superhost  \
# 0      2010-06-28                 NaN                 f
# 1      2010-08-09      within an hour                 f
# 2      2010-10-19  within a few hours                 f
# 3      2011-01-04  within a few hours                 f
# 4      2010-08-24  within a few hours                 t
# ...           ...                 ...               ...
# 26396  2018-01-28      within an hour                 f
# 26397  2020-07-24      within an hour               NaN
# 26398  2024-08-04      within an hour                 t
# 26399  2014-11-25      within an hour                 f
# 26400  2025-06-24                 NaN                 f
#
#       neighbourhood_cleansed        room_type  accommodates  \
# 0      Cuajimalpa de Morelos  Entire home/apt             2
# 1                 Cuauhtémoc  Entire home/apt            14
# 2                 Cuauhtémoc  Entire home/apt             2
# 3                 Cuauhtémoc  Entire home/apt             4
# 4                   Coyoacán  Entire home/apt             2
# ...                      ...              ...           ...
# 26396           Azcapotzalco  Entire home/apt             6
# 26397          Benito Juárez  Entire home/apt             2
# 26398             Cuauhtémoc  Entire home/apt             4
# 26399             Cuauhtémoc  Entire home/apt             2
# 26400         Miguel Hidalgo  Entire home/apt             6
#
#        number_of_reviews  review_scores_cleanliness  \
# 0                      0                        NaN
# 1                     65                       4.70
# 2                     84                       4.88
# 3                     50                       4.76
# 4                    132                       4.96
# ...                  ...                        ...
# 26396                  1                       5.00
# 26397                  0                        NaN
# 26398                  0                        NaN
# 26399                  0                        NaN
# 26400                  0                        NaN
#
#        review_scores_communication  review_scores_location
# 0                              NaN                     NaN
# 1                             4.78                    4.98
# 2                             4.94                    4.76
# 3                             4.92                    4.98
# 4                             4.98                    4.96
# ...                            ...                     ...
# 26396                         5.00                    4.00
# 26397                          NaN                     NaN
# 26398                          NaN                     NaN
# 26399                          NaN                     NaN
# 26400                          NaN                     NaN
#
# [26401 rows x 10 columns]

# %%
df_selecc.to_csv("MEXICO_LIMPIO_10.csv")

from google.colab import files


files.download("MEXICO_LIMPIO_10.csv")

# %%
import numpy as np
import matplotlib.pyplot as plt

# Carga de archivo
df = pd.read_csv("MEXICO_LIMPIO_10.csv")
df.head(5)
# Out:
#    Unnamed: 0  host_since  host_response_time host_is_superhost  \
# 0           0  2010-06-28                 NaN                 f
# 1           1  2010-08-09      within an hour                 f
# 2           2  2010-10-19  within a few hours                 f
# 3           3  2011-01-04  within a few hours                 f
# 4           4  2010-08-24  within a few hours                 t
#
#   neighbourhood_cleansed        room_type  accommodates  number_of_reviews  \
# 0  Cuajimalpa de Morelos  Entire home/apt             2                  0
# 1             Cuauhtémoc  Entire home/apt            14                 65
# 2             Cuauhtémoc  Entire home/apt             2                 84
# 3             Cuauhtémoc  Entire home/apt             4                 50
# 4               Coyoacán  Entire home/apt             2                132
#
#    review_scores_cleanliness  review_scores_communication  \
# 0                        NaN                          NaN
# 1                       4.70                         4.78
# 2                       4.88                         4.94
# 3                       4.76                         4.92
# 4                       4.96                         4.98
#
#    review_scores_location
# 0                     NaN
# 1                    4.98
# 2                    4.76
# 3                    4.98
# 4                    4.96

# %%
#Identificar valores nulos por columna
display(df.isnull().sum())
# Out:
# Unnamed: 0                        0
# host_since                      914
# host_response_time             4686
# host_is_superhost              1359
# neighbourhood_cleansed            0
# room_type                         0
# accommodates                      0
# number_of_reviews                 0
# review_scores_cleanliness      3375
# review_scores_communication    3375
# review_scores_location         3375
# dtype: int64

# %%
#Establecer un nombre específico "Unknown" a todas los valores nulos dentro de las columnas 'host_since'
df["host_since"] = df["host_since"].fillna("00/00/00")

display(df.isnull().sum())
# Out:
# Unnamed: 0                        0
# host_since                        0
# host_response_time             4686
# host_is_superhost              1359
# neighbourhood_cleansed            0
# room_type                         0
# accommodates                      0
# number_of_reviews                 0
# review_scores_cleanliness      3375
# review_scores_communication    3375
# review_scores_location         3375
# dtype: int64

# %%
## LLenamos los NAs de la columna de 'host_response_time' con el string más repetido; "within an hour"
valor_mas_repetido_response = df["host_response_time"].mode()[0]
print("El valor más repetido es:", valor_mas_repetido_response)

df["host_response_time"] = df["host_response_time"].fillna(valor_mas_repetido_response)

display(df.isnull().sum())
# Out:
# El valor más repetido es: within an hour
# Unnamed: 0                        0
# host_since                        0
# host_response_time                0
# host_is_superhost              1359
# neighbourhood_cleansed            0
# room_type                         0
# accommodates                      0
# number_of_reviews                 0
# review_scores_cleanliness      3375
# review_scores_communication    3375
# review_scores_location         3375
# dtype: int64

# %%
#Agregar nueva categoría 'NONE' a celdas vacias dentro de columna 'host_is_superhost'
df["host_is_superhost"] = df["host_is_superhost"].fillna("NONE")
display(df.isnull().sum())
# Out:
# Unnamed: 0                        0
# host_since                        0
# host_response_time                0
# host_is_superhost                 0
# neighbourhood_cleansed            0
# room_type                         0
# accommodates                      0
# number_of_reviews                 0
# review_scores_cleanliness      3375
# review_scores_communication    3375
# review_scores_location         3375
# dtype: int64

# %%
#Establecer con 0 todos los values que no cuentan con un review dentro este tipo de variables el dataframe
df['review_scores_cleanliness'] = df['review_scores_cleanliness'].fillna(0)
df['review_scores_communication'] = df['review_scores_communication'].fillna(0)
df['review_scores_location'] = df['review_scores_location'].fillna(0)
display(df.isnull().sum())
# Out:
# Unnamed: 0                     0
# host_since                     0
# host_response_time             0
# host_is_superhost              0
# neighbourhood_cleansed         0
# room_type                      0
# accommodates                   0
# number_of_reviews              0
# review_scores_cleanliness      0
# review_scores_communication    0
# review_scores_location         0
# dtype: int64

# %%
df.to_csv("MEXICO_FINAL_10.csv")

from google.colab import files


files.download("MEXICO_FINAL_10.csv")
